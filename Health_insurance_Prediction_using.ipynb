# %% [markdown]
# OBJECTIVE:
# To Predict insurance money,customer will get through ML Algorithm.
#
# TOOLS:
# Machine Learning Algorithm Model
#
# DATABASE DETAILS:
# The dataset describes clients's details like their health status,habbits,family details,region. On the basis of these factors the insurance claim is Derived.If the client gets the insurance,the target variable was marked as 'yes';otherwise it was marked as 'no'.
#
# Insurance Client Data Attributes:
#
#
# Input Variables:
#
# 1. age-(numeric)
#
# 2. sex-categorical,(female,male)
#
# 3. bmi-(numeric)
#
# 4. children-(numeric)
#
# 5. smoker-categorical,('yes','no')
#
# 6. region- categorical,('southwest','southeast','northwest','northeast')
#
# Output Variable (desired target)
#
# 7. -y- How much money will the client get from the insurance claim? (numeric value)

# %%
# Step-1 GATHERING DATA ,importing libraries

import numpy as np
import pandas as pd

# %%
# Loading the dataset
data=pd.read_csv("/content/insurance.csv")

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# Detailed Data Description

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
# to get unique value in each variable
data.apply(lambda x:len(x.unique())).sort_values(ascending=False)
# Out:
# expenses    1337
# bmi          275
# age           47
# children       6
# region         4
# sex            2
# smoker         2
# dtype: int64

# %%
# to find out shape of dataset
data.shape
# Out:
# (1338, 7)

# %%
# to extract the columns
len(data.columns)
# Out:
# 7

# %% [markdown]
# DATA CLEANING/WRANGLING
#
# Converting categorical datapoints into Numeric
# Using One Hot Encoding Technique

# %%
data['sex']=data['sex'].apply({'female':1,'male':0}.get)
data['smoker']=data['smoker'].apply({'yes':1,'no':0}.get)
data['region']=data['region'].apply({'southwest':1,'southeast':2,'northwest':3,'northeast':4}.get)

# %%
data.head()
# Out:
#    age  sex   bmi  children  smoker  region  expenses
# 0   19    1  27.9         0       1       1  16884.92
# 1   18    0  33.8         1       0       2   1725.55
# 2   28    0  33.0         3       0       2   4449.46
# 3   33    0  22.7         0       0       3  21984.47
# 4   32    0  28.9         0       0       3   3866.86

# %%
# checking if there any null value
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
# To extract the description of data in dataframe
data.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.494768    30.665471     1.094918     0.204783
# std      14.049960     0.500160     6.098382     1.205493     0.403694
# min      18.000000     0.000000    16.000000     0.000000     0.000000
# 25%      27.000000     0.000000    26.300000     0.000000     0.000000
# 50%      39.000000     0.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.700000     2.000000     0.000000
# max      64.000000     1.000000    53.100000     5.000000     1.000000
#
#             region      expenses
# count  1338.000000   1338.000000
# mean      2.484305  13270.422414
# std       1.104885  12110.011240
# min       1.000000   1121.870000
# 25%       2.000000   4740.287500
# 50%       2.000000   9382.030000
# 75%       3.000000  16639.915000
# max       4.000000  63770.430000

# %% [markdown]
# Dividing the data into dependent and independent Variables

# %%
x= data[['age','sex','bmi','children','smoker','region']]         # independent variables
y= data['expenses']                  # dependent variable

# %% [markdown]
# Splitting the dataset into Training and Testing set

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)   # 80% data used for testing (learning)

# %% [markdown]
# Creating our SMLM(Supervised Machine Learning Model) using Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression
regression= LinearRegression()            # we are activating  our algorithm

# %%
# training the model
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= regression.predict(x_test)

# %%
print(y_pred)
# Out:
# [26374.60825584 12877.19049436 29330.35804727 11362.2954554
#  15818.82220923  3405.76523544  2602.24252867  8070.37328665
#   1963.24150841  8067.08070993 10718.7311637   8193.44733388
#  11415.38772913  1806.93086059 32293.27191015  5329.3791307
#  17157.0479787   7223.68614272 16351.17864078 12608.7570969
#  35822.19593913 16893.16384081 11491.54135116 14485.18575631
#   9628.39368454 33667.10670066 36169.16848598 11230.44684147
#  19549.8026139  18792.70167184 34113.01665101  4001.00322336
#   1083.79983917 32101.96359263 15361.3051567   8087.53114919
#  11455.95429037 10324.71611472 12339.79889892  5741.72326125
#   4367.55925153  7128.94280826  7750.3297538  10806.71716138
#   4047.31229722 12728.99095055 13241.86383546 16174.06637426
#  35282.25830216 10196.48493489  9206.03481587 33454.73659254
#  25377.06666479  2912.93868894 13356.38486862 37392.15265842
#   9065.06038199  8992.13829821  3023.41832711  4516.04127821
#   4890.20054583 12572.17243816 11616.53315261 40391.61765885
#  11277.63172658 10405.26339819 12812.57419095  5518.49750218
#   2065.56221924  1047.08045555 12355.80349159  6935.24931413
#  34472.89296608  9440.39487971  2813.02163666 10717.18261189
#  10332.64084148 11606.21014232  8367.98758757 15622.0835541
#   4395.96410968 15889.46751921 12901.22365131   385.45616799
#  16400.09880571 11887.55166983  4384.46586929  7428.56960508
#  31370.77849458 10724.02283915 11255.60705445  9222.94143364
#  12757.99440387  5857.28097058 11695.39734142 33933.80516905
#   2688.02983521  5405.36787674 11905.54661614  1511.96608798
#  38211.732143   11680.75045325 14504.00085042  6466.87552366
#  11844.03988227 27470.8487618   2090.64480853  7396.61308531
#  11525.91410363 10542.28225164  2733.72720699 11613.23291779
#  30069.84491461  3936.53467795  4090.98459894 17735.33152554
#   6236.6968465   5757.56733975  7765.51957368  4922.03108582
#  12901.91297709  8671.86949189 17071.93724176  3339.24038187
#  17159.90630347 12872.95734709  3346.37967724 33986.80671217
#   9796.18981659 11623.76317858 15046.61050871  7805.16616066
#  10805.43306948 12607.4341088  16099.13088961 10418.3320424
#  38639.2788496   3547.70656193 35318.44778718 31724.33956495
#  30793.62235452   310.08260234 16501.87257374  9464.99156468
#  15910.42965208 40670.49986435 37584.905582   14672.77663125
#  16267.88572339  7099.02847653 12556.55374135 14138.85471191
#   9108.49419511  3088.92354869  9976.52051445 36932.07680819
#  38986.36408729 27076.98548189  6528.10086165 13232.27414522
#  38958.21975177 12140.28874678  2855.81286034 31631.32223243
#   2843.27794378  8425.01885651 11822.61380531  7161.97981646
#  17226.98192888  4026.16487408  3687.30234426 13327.86731963
#   4779.88142183  4972.96465161 10069.53784696 10868.96104435
#   6618.61104884  7440.3541574   6849.30149342  4567.32064844
#  10720.72643338  3588.20825564 35974.65986832 29842.87975273
#  10987.97184457  9653.00347643  6139.02150085 33390.8872386
#  16844.97207989  8605.19286926 28942.61443075 12018.11236281
#  28560.23245526  2921.69129541  2271.67793909 10407.43239718
#   7524.84426513 15722.79095382 14191.03220438 35026.97500166
#   4296.82711378 14825.89080797  6270.6447331   2083.71385067
#   3770.15226461 27110.33477332 13047.21128885 29830.00668984
#  14080.15847949  6145.56220105 13146.47408251  8358.497832
#   3753.38420078  6272.13224645  4297.6291304  12820.23445779
#   -274.78946801 10521.1035904    277.67925647  3637.40162558
#  13254.32077759 13344.10657185 30510.35924375  6886.96682261
#  27482.94559736 40859.5962756   7473.34334227  8744.95735663
#   6931.31031892 36711.3620235  30806.98132174 37330.50737062
#  12068.60676062  5826.35192291 23809.71165049  6271.33405888
#  13357.46936812  5326.10468517  7170.77533021  3004.9842128
#   3310.37548248 10740.88654963 15109.51402531  2969.44497533
#  16829.72659655 13069.67404198   190.92941914  9517.50720348
#  16958.71305667 10793.15477271 12497.25891375 11189.74555535
#  36952.83551961 38722.57176699 11416.19902362  3015.88385802
#   8426.05936174 11362.7335364   9430.77932638  7950.27415789
#   7649.59266194  9083.89751014  4735.42906373 11460.60847444
#  12373.19984273  3812.4277836   6904.07686182  5458.51717787]

# %%
# accuracy of SMLM
regression.score(x,y)
# Out:
# 0.7501120052816979

# %% [markdown]
# To make Predictions on top of new Customer Data

# %%
new_data={'age':32,'sex':0,'bmi':25,'children':2,'smoker':1,'region':3}
index=[1] # serial no is 1 as its one row dataset

# %%
# converting Dataset into Dataframe
my_data= pd.DataFrame(new_data,index)

# %%
my_data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   32    0   25         2       1       3

# %%
new_predictions = regression.predict(my_data)
print("The health insurance given to the new customer is",new_predictions)
# Out:
# The health insurance given to the new customer is [28738.64574965]

# %% [markdown]
# Insurance  another customer

# %%
new_data={'age':50,'sex':1,'bmi':30,'children':3,'smoker':0,'region':2}
index=[1]

# %%
my_data= pd.DataFrame(new_data,index)

# %%
my_data
# Out:
#    age  sex  bmi  children  smoker  region
# 1   50    1   30         3       0       2

# %%
new_predictions = regression.predict(my_data)
print("The health insurance given to the new customer is",new_predictions)
# Out:
# The health insurance given to the new customer is [11871.17877971]
